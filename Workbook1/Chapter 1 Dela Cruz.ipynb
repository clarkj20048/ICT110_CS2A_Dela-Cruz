# %% [markdown]
# #### Exercise 1

# %%
print('Hello world!') #the error in this code is that the "P" in the print is in capital letter.
# Out:
# Hello world!

# %%
print ('Hello world!') #the "(" is missing in this code.
# Out:
# 'Hello world!'

# %%
print('Hello world!') #the "'" in this code is missing.
# Out:
# Hello world!

# %%
print('Hello world!') #=has an extra "'".
# Out:
# Hello world!

# %% [markdown]
# #### Exercise 2

# %%
x = 43
x = x + 1  #the output is 44.
print(x)
# Out:
# 44

# %% [markdown]
# #### Exercise 3

# %%
x = 43        #The error ion this code is that the "X" is in capital letter.
x = x + 1
print(x)
# Out:
# 44
